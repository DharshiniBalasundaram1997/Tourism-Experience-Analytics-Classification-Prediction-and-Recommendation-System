# %% [markdown]
# ***importing libraries:***

# %%
import pandas as pd
import os

# %% [markdown]
# ***Specify the xlsx file path:***

# %%
Item = "C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/DataSet/Updated_Item.xlsx"
Mode = "C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/DataSet/Mode.xlsx"
Transaction = "C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/DataSet/Transaction.xlsx"
User = "C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/DataSet/User.xlsx"
Region = "C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/DataSet/Region.xlsx"
Type = "C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/DataSet/Type.xlsx"
City = "C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/DataSet/City.xlsx"
Continent = "C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/DataSet/Continent.xlsx"
Country = "C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/DataSet/Country.xlsx"

# %%
Item = pd.read_excel(Item)
Mode = pd.read_excel(Mode)
Transaction = pd.read_excel(Transaction)
User = pd.read_excel(User)
Region = pd.read_excel(Region)
Type = pd.read_excel(Type)
City = pd.read_excel(City)
Continent = pd.read_excel(Continent)
Country = pd.read_excel(Country)

# %% [markdown]
# ***Saving uncleaned DataSet file:***

# %%
# Create the directory if it doesn't exist
output_dir = 'C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Uncleaned_DataSet'
os.makedirs(output_dir, exist_ok=True)

# Now saving the file to csv
Item.to_csv(os.path.join(output_dir, 'Item.csv'), index=False)
Mode.to_csv(os.path.join(output_dir, 'Mode.csv'), index=False)
Transaction.to_csv(os.path.join(output_dir, 'Transaction.csv'), index=False)
User.to_csv(os.path.join(output_dir, 'User.csv'), index=False)
Region.to_csv(os.path.join(output_dir, 'Region.csv'), index=False)
Type.to_csv(os.path.join(output_dir, 'Type.csv'), index=False)
City.to_csv(os.path.join(output_dir, 'City.csv'), index=False)
Continent.to_csv(os.path.join(output_dir, 'Continent.csv'), index=False)
Country.to_csv(os.path.join(output_dir, 'Country.csv'), index=False)

# %% [markdown]
# ***Read csv file:***

# %%
Item = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Uncleaned_DataSet/Item.csv")
Mode = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Uncleaned_DataSet/Mode.csv")
Transaction = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Uncleaned_DataSet/Transaction.csv")
User = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Uncleaned_DataSet/User.csv")
Region = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Uncleaned_DataSet/Region.csv")
Type = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Uncleaned_DataSet/Type.csv")
City = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Uncleaned_DataSet/City.csv")
Continent = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Uncleaned_DataSet/Continent.csv")
Country = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Uncleaned_DataSet/Country.csv")

# %%
Item.head()
# Out:
#    AttractionId  AttractionCityId AttractionTypeId  \
# 0           369                 1               13
# 1           481                 1               13
# 2           640                 1               63
# 3           650                 1               13
# 4           673                 1               13
#
#                        Attraction  \
# 0               Kuta Beach - Bali
# 1                  Nusa Dua Beach
# 2  Sacred Monkey Forest Sanctuary
# 3                     Sanur Beach
# 4                  Seminyak Beach
#
#                                 AttractionAddress
# 0                                            Kuta
# 1  Semenanjung Nusa Dua, Nusa Dua 80517 Indonesia
# 2         Jl. Monkey Forest, Ubud 80571 Indonesia
# 3                                           Sanur
# 4                                        Seminyak

# %%
Mode.head()
# Out:
#    VisitModeId VisitMode
# 0            0         -
# 1            1  Business
# 2            2   Couples
# 3            3    Family
# 4            4   Friends

# %%
Transaction.head()
# Out:
#    TransactionId  UserId  VisitYear  VisitMonth  VisitMode  AttractionId  \
# 0              3   70456       2022          10          2           640
# 1              8    7567       2022          10          4           640
# 2              9   79069       2022          10          3           640
# 3             10   31019       2022          10          3           640
# 4             15   43611       2022          10          2           640
#
#    Rating
# 0       5
# 1       5
# 2       5
# 3       3
# 4       3

# %%
User.head()
# Out:
#    UserId  ContinentId  RegionId  CountryId  CityId
# 0      14            5        20        155   220.0
# 1      16            3        14        101  3098.0
# 2      20            4        15        109  4303.0
# 3      23            1         4         22   154.0
# 4      25            3        14        101  3098.0

# %%
Region.head()
# Out:
#             Region  RegionId  ContinentId
# 0                -         0            0
# 1   Central Africa         1            1
# 2      East Africa         2            1
# 3     North Africa         3            1
# 4  Southern Africa         4            1

# %%
Type.head()
# Out:
#    AttractionTypeId         AttractionType
# 0                 2          Ancient Ruins
# 1                10                Ballets
# 2                13                Beaches
# 3                19        Caverns & Caves
# 4                34  Flea & Street Markets

# %%
City.head()
# Out:
#    CityId      CityName  CountryId
# 0       0             -          0
# 1       1        Douala          1
# 2       2  South Region          1
# 3       3     N'Djamena          2
# 4       4        Kigali          3

# %%
Continent.head()
# Out:
#    ContinentId            Continent
# 0            0                    -
# 1            1               Africa
# 2            2              America
# 3            3                 Asia
# 4            4  Australia & Oceania

# %%
Country.head()
# Out:
#    CountryId   Country  RegionId
# 0          0         -         0
# 1          1  Cameroon         1
# 2          2      Chad         1
# 3          3    Rwanda         1
# 4          4  Ethiopia         2

# %% [markdown]
# ***Dataset information:***

# %%
Item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AttractionId       1698 non-null   int64
#  1   AttractionCityId   1698 non-null   int64
#  2   AttractionTypeId   1698 non-null   object
#  3   Attraction         1698 non-null   object
#  4   AttractionAddress  1698 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 66.5+ KB

# %%
Mode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   VisitModeId  6 non-null      int64
#  1   VisitMode    6 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
Transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52930 entries, 0 to 52929
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionId  52930 non-null  int64
#  1   UserId         52930 non-null  int64
#  2   VisitYear      52930 non-null  int64
#  3   VisitMonth     52930 non-null  int64
#  4   VisitMode      52930 non-null  int64
#  5   AttractionId   52930 non-null  int64
#  6   Rating         52930 non-null  int64
# dtypes: int64(7)
# memory usage: 2.8 MB

# %%
User.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33530 entries, 0 to 33529
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   UserId       33530 non-null  int64
#  1   ContinentId  33530 non-null  int64
#  2   RegionId     33530 non-null  int64
#  3   CountryId    33530 non-null  int64
#  4   CityId       33526 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 1.3 MB

# %%
Region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Region       22 non-null     object
#  1   RegionId     22 non-null     int64
#  2   ContinentId  22 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 660.0+ bytes

# %%
Type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AttractionTypeId  17 non-null     int64
#  1   AttractionType    17 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 404.0+ bytes

# %%
City.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9143 entries, 0 to 9142
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CityId     9143 non-null   int64
#  1   CityName   9142 non-null   object
#  2   CountryId  9143 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 214.4+ KB

# %%
Continent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ContinentId  6 non-null      int64
#  1   Continent    6 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
Country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CountryId  165 non-null    int64
#  1   Country    165 non-null    object
#  2   RegionId   165 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 4.0+ KB

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# > *1. Normalize Formatting:*

# %%
#strip leading and trailing whitespace from all column names:
Item.columns = Item.columns.str.strip()
Mode.columns = Mode.columns.str.strip()
Transaction.columns = Transaction.columns.str.strip()
User.columns = User.columns.str.strip()
Region.columns = Region.columns.str.strip()
Type.columns = Type.columns.str.strip()
City.columns = City.columns.str.strip()
Continent.columns = Continent.columns.str.strip()
Country.columns = Country.columns.str.strip()

# %% [markdown]
# > *2. Verifying How many null values are present in each columns:*

# %%
#Verifying How many null values are present in each columns:
a = Item.isna().sum().sort_values(ascending=False).reset_index()

#Rename columns
a.columns = ['Items', 'Missing_Value_Count']
a
# Out:
#                Items  Missing_Value_Count
# 0       AttractionId                    0
# 1   AttractionCityId                    0
# 2   AttractionTypeId                    0
# 3         Attraction                    0
# 4  AttractionAddress                    0

# %%
#Verifying How many null values are present in each columns:
b = Mode.isna().sum().sort_values(ascending=False).reset_index()
b

#Rename columns
b.columns = ['Mode', 'Missing_Value_Count']
b
# Out:
#           Mode  Missing_Value_Count
# 0  VisitModeId                    0
# 1    VisitMode                    0

# %%
#Verifying How many null values are present in each columns:
c = Transaction.isna().sum().sort_values(ascending=False).reset_index()
c

#Rename columns
c.columns = ['Transaction_Details', 'Missing_Value_Count']
c
# Out:
#   Transaction_Details  Missing_Value_Count
# 0       TransactionId                    0
# 1              UserId                    0
# 2           VisitYear                    0
# 3          VisitMonth                    0
# 4           VisitMode                    0
# 5        AttractionId                    0
# 6              Rating                    0

# %%
#Verifying How many null values are present in each columns:
d = User.isna().sum().sort_values(ascending=False).reset_index()
d

#Rename columns
d.columns = ['User_Details', 'Missing_Value_Count']
d
# Out:
#   User_Details  Missing_Value_Count
# 0       CityId                    4
# 1       UserId                    0
# 2  ContinentId                    0
# 3     RegionId                    0
# 4    CountryId                    0

# %%
#Verifying How many null values are present in each columns:
e = Region.isna().sum().sort_values(ascending=False).reset_index()
e

#Rename columns
e.columns = ['Region', 'Missing_Value_Count']
e
# Out:
#         Region  Missing_Value_Count
# 0       Region                    0
# 1     RegionId                    0
# 2  ContinentId                    0

# %%
#Verifying How many null values are present in each columns:
f = Type.isna().sum().sort_values(ascending=False).reset_index()
f

#Rename columns
f.columns = ['Type', 'Missing_Value_Count']
f
# Out:
#                Type  Missing_Value_Count
# 0  AttractionTypeId                    0
# 1    AttractionType                    0

# %%
#Verifying How many null values are present in each columns:
g = City.isna().sum().sort_values(ascending=False).reset_index()
g

#Rename columns
g.columns = ['City', 'Missing_Value_Count']
g
# Out:
#         City  Missing_Value_Count
# 0   CityName                    1
# 1     CityId                    0
# 2  CountryId                    0

# %%
#Verifying How many null values are present in each columns:
h = Continent.isna().sum().sort_values(ascending=False).reset_index()
h

#Rename columns
h.columns = ['Continent', 'Missing_Value_Count']
h
# Out:
#      Continent  Missing_Value_Count
# 0  ContinentId                    0
# 1    Continent                    0

# %%
#Verifying How many null values are present in each columns:
i = Country.isna().sum().sort_values(ascending=False).reset_index()
i

#Rename columns
i.columns = ['Country', 'Missing_Value_Count']
i
# Out:
#      Country  Missing_Value_Count
# 0  CountryId                    0
# 1    Country                    0
# 2   RegionId                    0

# %% [markdown]
# > *3. Handling Missing data/values: City and User csv file has null values on the columns of CityName and CityId*

# %% [markdown]
# - 1. Replacing the nan values in CityName column of City csv file:

# %%
City['CityName'] = City['CityName'].fillna('Not Determined')
City.head()
# Out:
#    CityId      CityName  CountryId
# 0       0             -          0
# 1       1        Douala          1
# 2       2  South Region          1
# 3       3     N'Djamena          2
# 4       4        Kigali          3

# %%
City.isna().sum().sort_values(ascending=False).reset_index()
# Out:
#        index  0
# 0     CityId  0
# 1   CityName  0
# 2  CountryId  0

# %% [markdown]
# - 2. Replacing the nan values in CityId column of User csv file:

# %%
User['CityId'].mode()[0]
# Out:
# np.float64(3551.0)

# %%
User['CityId'] = User['CityId'].fillna(User['CityId'].mode()[0])
User.head()
# Out:
#    UserId  ContinentId  RegionId  CountryId  CityId
# 0      14            5        20        155   220.0
# 1      16            3        14        101  3098.0
# 2      20            4        15        109  4303.0
# 3      23            1         4         22   154.0
# 4      25            3        14        101  3098.0

# %%
User.isna().sum().sort_values(ascending=False)
# Out:
# UserId         0
# ContinentId    0
# RegionId       0
# CountryId      0
# CityId         0
# dtype: int64

# %% [markdown]
# > *4. Mapping the values for AttractionTypeId in Item csv:*

# %%
# Define the mapping of AttractionType to AttractionTypeId
AttractionTypeId_mapping = {
    "Beach": 13,
    "Market": 34,
    "Museum": 64,
    "Park": 91,
    "Temple": 76
}

# Apply the mapping to update the AttractionTypeId column
Item['AttractionTypeId'] = Item['AttractionTypeId'].map(AttractionTypeId_mapping).fillna(Item['AttractionTypeId'])
Item
# Out:
#       AttractionId  AttractionCityId AttractionTypeId  \
# 0              369                 1               13
# 1              481                 1               13
# 2              640                 1               63
# 3              650                 1               13
# 4              673                 1               13
# ...            ...               ...              ...
# 1693          2961              8154             76.0
# 1694          2962              9142             76.0
# 1695          2963              9142             64.0
# 1696          2964              9142             91.0
# 1697          2965              9142             91.0
#
#                           Attraction  \
# 0                  Kuta Beach - Bali
# 1                     Nusa Dua Beach
# 2     Sacred Monkey Forest Sanctuary
# 3                        Sanur Beach
# 4                     Seminyak Beach
# ...                              ...
# 1693     Ancient Temple - Churchdown
# ...

# %%
Item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AttractionId       1698 non-null   int64
#  1   AttractionCityId   1698 non-null   int64
#  2   AttractionTypeId   1698 non-null   object
#  3   Attraction         1698 non-null   object
#  4   AttractionAddress  1698 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 66.5+ KB

# %%
Item['AttractionTypeId'] = Item['AttractionTypeId'].astype(int)

# %%
Item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AttractionId       1698 non-null   int64
#  1   AttractionCityId   1698 non-null   int64
#  2   AttractionTypeId   1698 non-null   int64
#  3   Attraction         1698 non-null   object
#  4   AttractionAddress  1698 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 66.5+ KB

# %% [markdown]
# > *4. Validating Data Relationships Between Tables - Data Model:*

# %% [markdown]
# - Column Names:

# %%
print("Item:\n", Item.columns)
print("Mode:\n", Mode.columns)
print("Transaction:\n", Transaction.columns)
print("User:\n", User.columns)
print("Region:\n", Region.columns)
print("Type:\n", Type.columns)
print("City:\n", City.columns)
print("Continent:\n", Continent.columns)
print("Country:\n", Country.columns)
# Out:
# Item:
#  Index(['AttractionId', 'AttractionCityId', 'AttractionTypeId', 'Attraction',
#        'AttractionAddress'],
#       dtype='object')
# Mode:
#  Index(['VisitModeId', 'VisitMode'], dtype='object')
# Transaction:
#  Index(['TransactionId', 'UserId', 'VisitYear', 'VisitMonth', 'VisitMode',
#        'AttractionId', 'Rating'],
#       dtype='object')
# User:
#  Index(['UserId', 'ContinentId', 'RegionId', 'CountryId', 'CityId'], dtype='object')
# Region:
#  Index(['Region', 'RegionId', 'ContinentId'], dtype='object')
# Type:
#  Index(['AttractionTypeId', 'AttractionType'], dtype='object')
# City:
#  Index(['CityId', 'CityName', 'CountryId'], dtype='object')
# Continent:
#  Index(['ContinentId', 'Continent'], dtype='object')
# Country:
#  Index(['CountryId', 'Country', 'RegionId'], dtype='object')

# %% [markdown]
# - ER Model:

# %%
# User (UserId) ──┬─→ City (CityId) ──→ Country (CountryId) ──→ Region (RegionId) ──→ Continent (ContinentId)
#                 │
#                 └─→ Transaction (TransactionId)
#                             │
#                             ├─→ Item (AttractionId)
#                             │       └─→ Type (AttractionTypeId)
#                             │       └─→ City (AttractionCityId)
#                             └─→ Mode (VisitMode)

# %% [markdown]
# [View ER Diagram](https://dbdiagram.io/d/684445175a9a94714e55d6fd)

# %%
from IPython.display import Image
Image("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/ER-MODEL.png")

# %% [markdown]
# - No.Of. Rows & Columns:

# %%
print("Item:",Item.shape)
print("Mode:",Mode.shape)
print("Transaction:", Transaction.shape)
print("User:", User.shape)
print("Region:", Region.shape)
print("Type:", Type.shape)
print("City:", City.shape)
print("Continent:", Continent.shape)
print("Country:", Country.shape)
# Out:
# Item: (1698, 5)
# Mode: (6, 2)
# Transaction: (52930, 7)
# User: (33530, 5)
# Region: (22, 3)
# Type: (17, 2)
# City: (9143, 3)
# Continent: (6, 2)
# Country: (165, 3)

# %% [markdown]
# - Validate all relationships:

# %%
# 1. Transaction.VisitMode → Mode.VisitModeId
Transaction = Transaction[Transaction['VisitMode'].isin(Mode['VisitModeId'])]

# 2. Item.AttractionTypeId → Type.AttractionTypeId
Item = Item[Item['AttractionTypeId'].isin(Type['AttractionTypeId'])]

# 3. User.CityId → City.CityId
User = User[User['CityId'].isin(City['CityId'])]

# 4. City.CountryId → Country.CountryId
City = City[City['CountryId'].isin(Country['CountryId'])]

# 5. Country.RegionId → Region.RegionId
Country = Country[Country['RegionId'].isin(Region['RegionId'])]

# 6. Region.ContinentId → Continent.ContinentId
Region = Region[Region['ContinentId'].isin(Continent['ContinentId'])]

# %%
print("Item:",Item.shape)
print("Mode:",Mode.shape)
print("Transaction:", Transaction.shape)
print("User:", User.shape)
print("Region:", Region.shape)
print("Type:", Type.shape)
print("City:", City.shape)
print("Continent:", Continent.shape)
print("Country:", Country.shape)
# Out:
# Item: (1698, 5)
# Mode: (6, 2)
# Transaction: (52930, 7)
# User: (33530, 5)
# Region: (22, 3)
# Type: (17, 2)
# City: (9143, 3)
# Continent: (6, 2)
# Country: (165, 3)

# %% [markdown]
# > *5. Standardize date and time format:*

# %%
# Combine VisitYear and VisitMonth into a datetime column (default day = 1)
Transaction['VisitDate'] = pd.to_datetime(dict(
    year=Transaction['VisitYear'],
    month=Transaction['VisitMonth'],
    day=1
))

Transaction
# Out:
#        TransactionId  UserId  VisitYear  VisitMonth  VisitMode  AttractionId  \
# 0                  3   70456       2022          10          2           640
# 1                  8    7567       2022          10          4           640
# 2                  9   79069       2022          10          3           640
# 3                 10   31019       2022          10          3           640
# 4                 15   43611       2022          10          2           640
# ...              ...     ...        ...         ...        ...           ...
# 52925         211227   87100       2018           9          2          1297
# 52926         211238   88112       2016           2          2          1297
# 52927         211239   88112       2016           2          2          1297
# 52928         211240   88112       2016           2          2          1297
# 52929         211241   88112       2016           2          2          1297
#
#        Rating  VisitDate
# ...

# %%
Transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52930 entries, 0 to 52929
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionId  52930 non-null  int64
#  1   UserId         52930 non-null  int64
#  2   VisitYear      52930 non-null  int64
#  3   VisitMonth     52930 non-null  int64
#  4   VisitMode      52930 non-null  int64
#  5   AttractionId   52930 non-null  int64
#  6   Rating         52930 non-null  int64
#  7   VisitDate      52930 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(7)
# memory usage: 3.2 MB

# %% [markdown]
# > *6. Handle outliers:*
#
# To Handle Outlier, either use Domain-based rules (e.g., Rating should be between 1 and 5) or use Statistical rules(e.g., IQR)

# %%
# Domain-based rules (e.g., Rating should be between 1 and 5)
Transaction = Transaction[(Transaction['Rating'] >= 1) & (Transaction['Rating'] <= 5)]
Transaction
# Out:
#        TransactionId  UserId  VisitYear  VisitMonth  VisitMode  AttractionId  \
# 0                  3   70456       2022          10          2           640
# 1                  8    7567       2022          10          4           640
# 2                  9   79069       2022          10          3           640
# 3                 10   31019       2022          10          3           640
# 4                 15   43611       2022          10          2           640
# ...              ...     ...        ...         ...        ...           ...
# 52925         211227   87100       2018           9          2          1297
# 52926         211238   88112       2016           2          2          1297
# 52927         211239   88112       2016           2          2          1297
# 52928         211240   88112       2016           2          2          1297
# 52929         211241   88112       2016           2          2          1297
#
#        Rating  VisitDate
# ...

# %% [markdown]
# > *7. Handle any incorrect entries other columns:*

# %%
# Example: Remove rows with invalid details
City = City[City['CityId'] != 0]
Item = Item[Item['AttractionCityId'] != 0]
Region = Region[Region['RegionId'] != 0]
Mode = Mode[Mode['VisitModeId'] != 0]
Continent = Continent[Continent['ContinentId'] != 0]
Country = Country[Country['CountryId'] != 0]

# %%
Item
# Out:
#       AttractionId  AttractionCityId  AttractionTypeId  \
# 0              369                 1                13
# 1              481                 1                13
# 2              640                 1                63
# 3              650                 1                13
# 4              673                 1                13
# ...            ...               ...               ...
# 1693          2961              8154                76
# 1694          2962              9142                76
# 1695          2963              9142                64
# 1696          2964              9142                91
# 1697          2965              9142                91
#
#                           Attraction  \
# 0                  Kuta Beach - Bali
# 1                     Nusa Dua Beach
# 2     Sacred Monkey Forest Sanctuary
# 3                        Sanur Beach
# 4                     Seminyak Beach
# ...                              ...
# ...

# %%
Mode
# Out:
#    VisitModeId VisitMode
# 1            1  Business
# 2            2   Couples
# 3            3    Family
# 4            4   Friends
# 5            5      Solo

# %%
Transaction
# Out:
#        TransactionId  UserId  VisitYear  VisitMonth  VisitMode  AttractionId  \
# 0                  3   70456       2022          10          2           640
# 1                  8    7567       2022          10          4           640
# 2                  9   79069       2022          10          3           640
# 3                 10   31019       2022          10          3           640
# 4                 15   43611       2022          10          2           640
# ...              ...     ...        ...         ...        ...           ...
# 52925         211227   87100       2018           9          2          1297
# 52926         211238   88112       2016           2          2          1297
# 52927         211239   88112       2016           2          2          1297
# 52928         211240   88112       2016           2          2          1297
# 52929         211241   88112       2016           2          2          1297
#
#        Rating  VisitDate
# ...

# %%
Transaction.rename(columns={'VisitMode': 'VisitModeId'}, inplace=True)
Transaction
# Out:
#        TransactionId  UserId  VisitYear  VisitMonth  VisitModeId  \
# 0                  3   70456       2022          10            2
# 1                  8    7567       2022          10            4
# 2                  9   79069       2022          10            3
# 3                 10   31019       2022          10            3
# 4                 15   43611       2022          10            2
# ...              ...     ...        ...         ...          ...
# 52925         211227   87100       2018           9            2
# 52926         211238   88112       2016           2            2
# 52927         211239   88112       2016           2            2
# 52928         211240   88112       2016           2            2
# 52929         211241   88112       2016           2            2
#
#        AttractionId  Rating  VisitDate
# 0               640       5 2022-10-01
# 1               640       5 2022-10-01
# 2               640       5 2022-10-01
# ...

# %%
User
# Out:
#        UserId  ContinentId  RegionId  CountryId  CityId
# 0          14            5        20        155   220.0
# 1          16            3        14        101  3098.0
# 2          20            4        15        109  4303.0
# 3          23            1         4         22   154.0
# 4          25            3        14        101  3098.0
# ...       ...          ...       ...        ...     ...
# 33525   88179            5        21        162  7833.0
# 33526   88185            3        12         80  2534.0
# 33527   88187            3        12         88  2604.0
# 33528   88189            5        17        131  6129.0
# 33529   88190            5        21        159  7494.0
#
# [33530 rows x 5 columns]

# %%
Region
# Out:
#               Region  RegionId  ContinentId
# 1     Central Africa         1            1
# 2        East Africa         2            1
# 3       North Africa         3            1
# 4    Southern Africa         4            1
# 5        West Africa         5            1
# 6          Caribbean         6            2
# 7    Central America         7            2
# 8   Northern America         8            2
# 9      South America         9            2
# 10      Central Asia        10            3
# 11         East Asia        11            3
# 12       Middle East        12            3
# 13        South Asia        13            3
# 14   South East Asia        14            3
# 15         Australia        15            4
# 16           Oceania        16            4
# 17    Central Europe        17            5
# 18    Eastern Europe        18            5
# 19   Northern Europe        19            5
# 20   Southern Europe        20            5
# ...

# %%
Type
# Out:
#     AttractionTypeId                  AttractionType
# 0                  2                   Ancient Ruins
# 1                 10                         Ballets
# 2                 13                         Beaches
# 3                 19                 Caverns & Caves
# 4                 34           Flea & Street Markets
# 5                 44                  Historic Sites
# 6                 45                 History Museums
# 7                 61                  National Parks
# 8                 63         Nature & Wildlife Areas
# 9                 64                   Neighborhoods
# 10                72  Points of Interest & Landmarks
# 11                76                 Religious Sites
# 12                82                            Spas
# 13                84              Speciality Museums
# 14                91                        Volcanos
# 15                92                     Water Parks
# 16                93                      Waterfalls

# %%
City
# Out:
#       CityId         CityName  CountryId
# 1          1           Douala          1
# 2          2     South Region          1
# 3          3        N'Djamena          2
# 4          4           Kigali          3
# 5          5  Kigali Province          3
# ...      ...              ...        ...
# 9138    9138           Yeovil        163
# 9139    9139             York        163
# 9140    9140        Yorkshire        163
# 9141    9141          Zaandam        163
# 9142    9142            Sanaa        164
#
# [9142 rows x 3 columns]

# %%
Continent
# Out:
#    ContinentId            Continent
# 1            1               Africa
# 2            2              America
# 3            3                 Asia
# 4            4  Australia & Oceania
# 5            5               Europe

# %%
Country
# Out:
#      CountryId         Country  RegionId
# 1            1        Cameroon         1
# 2            2            Chad         1
# 3            3          Rwanda         1
# 4            4        Ethiopia         2
# 5            5           Kenya         2
# ..         ...             ...       ...
# 160        160         Ireland        21
# 161        161          Monaco        21
# 162        162     Netherlands        21
# 163        163  United Kingdom        21
# 164        164           Yemen        12
#
# [164 rows x 3 columns]

# %% [markdown]
# **Saving the cleaned DataSet:**

# %%
# Create the directory if it doesn't exist
output_dir = 'C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Clean_DataSet'
os.makedirs(output_dir, exist_ok=True)

# Now saving the file to csv
Item.to_csv(os.path.join(output_dir, 'Item.csv'), index=False)
Mode.to_csv(os.path.join(output_dir, 'Mode.csv'), index=False)
Transaction.to_csv(os.path.join(output_dir, 'Transaction.csv'), index=False)
User.to_csv(os.path.join(output_dir, 'User.csv'), index=False)
Region.to_csv(os.path.join(output_dir, 'Region.csv'), index=False)
Type.to_csv(os.path.join(output_dir, 'Type.csv'), index=False)
City.to_csv(os.path.join(output_dir, 'City.csv'), index=False)
Continent.to_csv(os.path.join(output_dir, 'Continent.csv'), index=False)
Country.to_csv(os.path.join(output_dir, 'Country.csv'), index=False)



Item = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Clean_DataSet/Item.csv")
Mode = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Clean_DataSet/Mode.csv")
Transaction = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Clean_DataSet/Transaction.csv")
User = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Clean_DataSet/User.csv")
Region = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Clean_DataSet/Region.csv")
Type = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Clean_DataSet/Type.csv")
City = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Clean_DataSet/City.csv")
Continent = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Clean_DataSet/Continent.csv")
Country = pd.read_csv("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project4/Project4_Code/Tourism_Experince_Analytics/DataSets/Clean_DataSet/Country.csv")
